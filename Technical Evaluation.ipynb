# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('C:\\Users\\Square Bear\\Documents\\Thinkful\\Datasets\\plane_crashes_data.csv')

print(df.columns)
print('\n')
print(df.dtypes)
# Out:
# Index(['month', 'hour', 'year', 'location', 'operator', 'route', 'type',
#        'aboard', 'fatalities', 'summary'],
#       dtype='object')
#
#
# month          int64
# hour          object
# year           int64
# location      object
# operator      object
# route         object
# type          object
# aboard         int64
# fatalities     int64
# summary       object
# dtype: object

# %%
df.head(10)
# Out:
#    month hour  year                         location  \
# 0      1   12  1950              Near Vacas, Bolivia
# 1      3   20  1950           Minneapolis, Minnesota
# 2      3   14  1950  Llandow Airport, Cardiff, Wales
# 3      4   23  1950               Near Atsugi, Japan
# 4      5   20  1950    Lagens Air Force Base, Azores
# 5      5   10  1950     Myrtle Beach, South Carolina
# 6      5   17  1950            Teterboro, New Jersey
# 7      6   22  1950         AtlantiOcean off Florida
# 8      6   19  1950           Near Fonseca, Colombia
# 9      6   21  1950                      Off Bahrain
#
#                         operator                                     route  \
# 0  Military - Bolivian Air Force                 Valle grande - Cochabamba
# 1      Northwest Orient Airlines             Rochester Minn. - Minneapolis
# 2                Fairflight Ltd.                          Llandow - Dublin
# 3      Military - U.S. Air Force                       Philippines - Japan
# ...

# %%
df.tail(10)
# Out:
#       month hour  year                                           location  \
# 2699      4   14  2009                              Off Crimond, Scotland
# 2700      4   12  2009                                 Bandung, Indonesia
# 2701      4    7  2009                             Near Wamena, Indonesia
# 2702      4   10  2009                           Mount Gergaji, Indonesia
# 2703      4   15  2009                   Canaima National Park, Venezuela
# 2704      4    6  2009                 Massamba, DemocratiRepubliof Congo
# 2705      5   12  2009                   Near El Alto de Rubio, Venezuela
# 2706      5    6  2009                             Near Madiun, Indonesia
# 2707      6    0  2009  AtlantiOcean, 570 miles northeast of Natal, Br...
# 2708      6    8  2009       Near Port Hope Simpson, Newfoundland, Canada
#
#                              operator  \
# 2699        Bond Offshore Helicopters
# 2700  Military - Indonesian Air Force
# ...

# %%
df.loc[lambda df: df['year'] >= 1980, 'fatalities'].mean()
# Out:
# 24.932607215793055

# %%
month_max_crash = df.loc[lambda df: df['year'] >= 1950, : ].groupby('month').count()
print(month_max_crash)
# Out:
#        hour  year  location  operator  route  type  aboard  fatalities  \
# month
# 1       255   255       255       255    220   255     255         255
# 2       209   209       208       209    180   209     209         209
# 3       251   251       250       250    208   251     251         251
# 4       204   204       204       204    163   203     204         204
# 5       181   181       180       181    158   181     181         181
# 6       202   202       202       202    174   202     202         202
# 7       234   234       234       234    202   234     234         234
# 8       239   239       239       239    211   239     239         239
# 9       228   228       228       228    200   228     228         228
# 10      224   224       224       223    186   224     224         224
# 11      230   230       230       230    196   230     230         230
# 12      252   252       252       252    220   252     252         252
#
#        summary
# month
# ...

# %%
df[(df.year>=1960)&(df.year<=1970)]
# Out:
#      month hour  year                                          location  \
# 303      1   10  1960                                    Taksing, India
# 304      1    2  1960                Wilmington/Bolivia, North Carolina
# 305      1   15  1960                                     Gulf of Sirte
# 306      1   22  1960                            Charles City, Virginia
# 307      1   18  1960                                    Ankara, Turkey
# 308      1    0  1960                    Off Bathurst Island, Australia
# 309      2   13  1960                            Rio de Janeiro, Brazil
# 310      3   15  1960  Near Cannelton, 10 mile SE of Tell City, Indiana
# 311      3   11  1960                                 Cordoba, Colombia
# 312      4   14  1960                                  Siuna, Nicaragua
# 313      4   14  1960                                   Pelotas, Brazil
# 314      4   20  1960                                  Bogota, Colombia
# ...

# %%
df.isna().sum()
# Out:
# month           0
# hour            0
# year            0
# location        3
# operator        2
# route         391
# type            1
# aboard          0
# fatalities      0
# summary        13
# dtype: int64

# %%
df = df.fillna(df.mean())
df.head(10)
# Out:
#    month hour  year                         location  \
# 0      1   12  1950              Near Vacas, Bolivia
# 1      3   20  1950           Minneapolis, Minnesota
# 2      3   14  1950  Llandow Airport, Cardiff, Wales
# 3      4   23  1950               Near Atsugi, Japan
# 4      5   20  1950    Lagens Air Force Base, Azores
# 5      5   10  1950     Myrtle Beach, South Carolina
# 6      5   17  1950            Teterboro, New Jersey
# 7      6   22  1950         AtlantiOcean off Florida
# 8      6   19  1950           Near Fonseca, Colombia
# 9      6   21  1950                      Off Bahrain
#
#                         operator                                     route  \
# 0  Military - Bolivian Air Force                 Valle grande - Cochabamba
# 1      Northwest Orient Airlines             Rochester Minn. - Minneapolis
# 2                Fairflight Ltd.                          Llandow - Dublin
# 3      Military - U.S. Air Force                       Philippines - Japan
# ...

# %%
list = ['location','operator','route','type','summary']

for i in list:
     df[i] = df[i].fillna(df[i].mode()[0])

df.head(10)
# Out:
#    month hour  year                         location  \
# 0      1   12  1950              Near Vacas, Bolivia
# 1      3   20  1950           Minneapolis, Minnesota
# 2      3   14  1950  Llandow Airport, Cardiff, Wales
# 3      4   23  1950               Near Atsugi, Japan
# 4      5   20  1950    Lagens Air Force Base, Azores
# 5      5   10  1950     Myrtle Beach, South Carolina
# 6      5   17  1950            Teterboro, New Jersey
# 7      6   22  1950         AtlantiOcean off Florida
# 8      6   19  1950           Near Fonseca, Colombia
# 9      6   21  1950                      Off Bahrain
#
#                         operator                                     route  \
# 0  Military - Bolivian Air Force                 Valle grande - Cochabamba
# 1      Northwest Orient Airlines             Rochester Minn. - Minneapolis
# 2                Fairflight Ltd.                          Llandow - Dublin
# 3      Military - U.S. Air Force                       Philippines - Japan
# ...

# %%
df['fatalities'].max()
# Out:
# 583

# %%
len(df.loc[lambda df: df['fatalities'] > 0, :]['fatalities']) / len(df)
# Out:
# 0.9819121447028424

# %%
(df['fatalities']/df['aboard']).mean()
# Out:
# 0.8231319223510563
